# %%
import hangul_font
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import openpyxl
import os
import time
import math
import webbrowser
import numpy as np
import re
import sys
import csv

df = pd.read_csv('data_visual.txt2023-1-7-8해시태그 by 스타일.csv',encoding='cp949')
df.drop('Unnamed: 0',axis='columns',inplace =True)
df.rename(columns = {'cordi':'코디','0':'날짜','1':'조회수','2':'댓글'},inplace=True)
df.drop(columns=['댓글'], inplace=True)
df
# Out:
#            날짜   코디    조회수      3    4       5          6        7        8  \
# 0    20210730  캐주얼  35753  로고플레이  편안한   원마일웨어       와이드핏       여름      캐주얼
# 1    20210203  스트릿  33411      봄  스트릿      제로         월간   라퍼지스토어    키치오브제
# 2    20210223  캐주얼  31119      봄  캐주얼  라퍼지스토어  다이아몬드 레이라      나이키     엠프렌즈
# 3    20201029  스트릿  27571     가을  스트릿      제로       쇼브오프   라퍼지스토어      크리틱
# 4    20210430   댄디  27238      봄   댄디  후러브스아트    발렌티노 루디  오니츠카타이거       예일
# ..        ...  ...    ...    ...  ...     ...        ...      ...      ...
# 995  20210729  캐주얼   9633    모노톤  단정한     남친룩         레더      데이트       여름
# 996  20201113  캐주얼   9633    아가일   가을      댄디     커스텀에이드     브랜디드   벤 데이비스
# 997  20211112  스포츠   9587     워싱  미니멀     남친룩        데이트      얼죽코      셀럽템
# 998  20201104  캐주얼   9567     가을  캐주얼      제멋       위캔더스       반스  바이시클트로피
# 999  20211224  캐주얼   9564    남친룩   레더     데이트      테이퍼드핏      오버핏      소개팅
#
# ...

# %%
print(df['날짜'].to_numpy().max())
print(df['날짜'].to_numpy().min())

filter_2021 = (df['날짜']>=20210101)&(df['날짜']<=20211231)
filter_2022 = (df['날짜']>=20220101)&(df['날짜']<=20221231)

df_2021style=df[filter_2021]
df_2022style=df[filter_2022]
n = time.localtime()
s = f'{n.tm_year}-{n.tm_mon}-{n.tm_mday}-{n.tm_sec}'
f_dir = "c:\\temp\\"+s
fc_name = f_dir+'2022_trend_style' + '.csv'
df_2022style.to_csv(fc_name,encoding='cp949') 

fc_name2 = f_dir+'2021_trend_style' + '.csv'
df_2021style.to_csv(fc_name2,encoding='cp949')
# Out:
# 20221028
# 20201027
